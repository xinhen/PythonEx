# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

g=nx.Graph()
g.add_node('no-1')
g.add_nodes_from(['no-2','no-3'])
g.add_nodes_from([('no-4',{'id':1,'operation':'add'})])
nx.draw(g,with_labels=True)

print(g.number_of_edges())
print(g.edges)
plt.show()
# Out:
# 0
# []

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

G=nx.Graph()
G.add_edges_from(([1,2],[2,3],[3,1]))
e=[(1,2),(2,3),(3,4)]
G2=nx.Graph(e)
F=G.to_directed()
H=nx.MultiDiGraph(e)
plt.subplot(2,2,1)
nx.draw(G,with_labels=True)
plt.subplot(222)
nx.draw(G2,with_labels=True)
plt.subplot(223)
nx.draw(F,with_labels=True)
plt.subplot(224)
nx.draw(H,with_labels=True)
plt.show()
# Out:
# E:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

G=nx.Graph()
G.add_node(1,time='5pm')
G.add_nodes_from([1,2,3],time='5pm')
G.add_nodes_from([(3,{'time':'5pm'}),(4,{'time':'4pm'})])
print(G.node[1]['time'])

# G.add_edge('1','2',time='3am')
G.add_edges_from([(1,2,{'time':'5pm'}),(2,3,{'time':'3am'})])
print(G.edges())
print(G[1][2])
plt.subplot(121)
nx.draw(G,with_labels=True)
time=nx.get_edge_attributes(G,'time')
print(time[(1,2)])
print(G.adj.items())
for a,ite in G.adj.items():
    print(ite.items())
    for b,itt in ite.items():
        print(itt)
plt.show()
# Out:
# 5pm
# [(1, 2), (2, 3)]
# {'time': '5pm'}
# 5pm
# ItemsView(AdjacencyView({1: {2: {'time': '5pm'}}, 2: {1: {'time': '5pm'}, 3: {'time': '3am'}}, 3: {2: {'time': '3am'}}, 4: {}}))
# ItemsView(AtlasView({2: {'time': '5pm'}}))
# {'time': '5pm'}
# ItemsView(AtlasView({1: {'time': '5pm'}, 3: {'time': '3am'}}))
# {'time': '5pm'}
# {'time': '3am'}
# ItemsView(AtlasView({2: {'time': '3am'}}))
# {'time': '3am'}
# ItemsView(AtlasView({}))

# %%
import networkx as nx
from networkx.algorithms import bipartite

B=nx.Graph()
B.add_nodes_from([1,2,3,4],bipartite=0)
B.add_nodes_from(['a','b','c'],bipartite=1)
B.add_edges_from([(1,'a'),(1,'b'),(2,'b'),(2,'c'),(3,'c'),(4,'a')])

print(nx.is_connected(B))
bot_node,top_nodes=bipartite.sets(B)
print(bot_node)
print(top_nodes)
# Out:
# True
# {1, 2, 3, 4}
# {'c', 'b', 'a'}

# %%
import pandas as pd
pd.options.display.max_columns = 20
import numpy as np
rng=np.random.RandomState(seed=5)
ints=rng.randint(1,11,size=(3,2))
a=['A','B','C']
b=['D','A','E']
df=pd.DataFrame(ints,columns=['weight','cost'])
df['source']=a
df['target']=b


edges=pd.DataFrame({'source':[0,1,2],'target':[2,2,3],'weight':[3,4,5],'color':['red','blue','blue']})

G2=nx.from_pandas_edgelist(edges,edge_attr=True)

G=nx.from_pandas_edgelist(df,'source','target',['weight','cost'])
print(G2[0][2]['color'])
nx.drawing.nx_pylab.draw_circular(G2,with_labels=True)
plt.show()
# Out:
# red
# E:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
